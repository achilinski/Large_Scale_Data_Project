# %%
# %run runtime-analysis-2.py
# Out:
# ...
# Testing Configuration 1/7
# ...
# {
#   "USE_CACHING": false,
#   "USE_BROADCAST_JOIN": false,
#   "EARLY_COLUMN_PROJECTION": false,
#   "OPTIMIZE_PARTITIONING": false,
#   "OPTIMIZED_FILTER_ORDER": false
# }
#
#   Iteration 1/3...
#   Runtime: 60.44s
#
#   Iteration 2/3...
#   Runtime: 58.90s
#
#   Iteration 3/3...
#   Runtime: 69.00s
#
# ...
# Testing Configuration 2/7
# ...
# {
#   "USE_CACHING": true,
#   "USE_BROADCAST_JOIN": false,
#   "EARLY_COLUMN_PROJECTION": false,
#   "OPTIMIZE_PARTITIONING": false,
#   "OPTIMIZED_FILTER_ORDER": false
# }
#
#   Iteration 1/3...
#   Runtime: 171.39s
#
#   Iteration 2/3...
#   Runtime: 181.94s
#
#   Iteration 3/3...
#   Runtime: 154.71s
#
# ...
# Testing Configuration 3/7
# ...
# {
#   "USE_CACHING": false,
#   "USE_BROADCAST_JOIN": true,
#   "EARLY_COLUMN_PROJECTION": false,
#   "OPTIMIZE_PARTITIONING": false,
#   "OPTIMIZED_FILTER_ORDER": false
# }
#
#   Iteration 1/3...
#   Runtime: 63.67s
#
#   Iteration 2/3...
#   Runtime: 70.24s
#
#   Iteration 3/3...
# ...
